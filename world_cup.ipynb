# %%
import pandas as pd
import numpy as np

# %%
# Do conda installations

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_finals#:~:text=With%20five%20titles%2C%20Brazil%20is,and%20Spain%20have%20one%20each.')

# %%
df[0]
# Out:
#                                                    0  \
# 0  France celebrating after their win against Cro...
# 1                                            Founded
# 2                                  Current champions
# 3                            Most successful team(s)
#
#                                                    1
# 0  France celebrating after their win against Cro...
# 1                                 1930; 92 years ago
# 2                                 France (2nd title)
# 3                                  Brazil (5 titles)

# %%
df[1]
# Out:
#                                                    0  \
# 0  .mw-parser-output .locmap .od{position:absolut...
#
#                                                    1
# 0  Montevideo (1930)Buenos Aires(1978)Rio de Jane...

# %%
df[2]
# Out:
#         0                                     1
# 0  a.e.t.       Match was won during extra time
# 1    pen.  Match was won on a penalty shoot-out

# %%
df[3]
# Out:
#                Year          Winners                Score[2]       Runners-up  \
# 0              1930          Uruguay                     4–2        Argentina
# 1              1934            Italy            2–1 (a.e.t.)   Czechoslovakia
# 2              1938            Italy                     4–2          Hungary
# 3              1950          Uruguay                   [n 3]           Brazil
# 4              1954     West Germany                     3–2          Hungary
# 5              1958           Brazil                     5–2           Sweden
# 6              1962           Brazil                     3–1   Czechoslovakia
# 7              1966          England            4–2 (a.e.t.)     West Germany
# 8              1970           Brazil                     4–1            Italy
# 9              1974     West Germany                     2–1      Netherlands
# 10             1978        Argentina            3–1 (a.e.t.)      Netherlands
# ...

# %%
df = df[3]

# %%
df = df[:21]

# %%
df.tail()
# Out:
#     Year  Winners                Score[2]   Runners-up                  Venue  \
# 16  2002   Brazil                     2–0      Germany  International Stadium
# 17  2006    Italy  1–1 (a.e.t.)(5–3 pen.)       France         Olympiastadion
# 18  2010    Spain            1–0 (a.e.t.)  Netherlands            Soccer City
# 19  2014  Germany            1–0 (a.e.t.)    Argentina       Maracanã Stadium
# 20  2018   France                     4–2      Croatia       Luzhniki Stadium
#
#                       Location Attendance        country
# 16             Yokohama, Japan      69029          Japan
# 17             Berlin, Germany      69000        Germany
# 18  Johannesburg, South Africa      84490   South Africa
# 19      Rio de Janeiro, Brazil      74738         Brazil
# 20              Moscow, Russia      78011         Russia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        21 non-null     object
#  1   Winners     21 non-null     object
#  2   Score[2]    21 non-null     object
#  3   Runners-up  21 non-null     object
#  4   Venue       21 non-null     object
#  5   Location    21 non-null     object
#  6   Attendance  21 non-null     object
#  7   Refs        21 non-null     object
# dtypes: object(8)
# memory usage: 1.4+ KB

# %%
df = df.drop(['Refs'], axis=1)

# %%
df['Venue'].value_counts()
# Out:
# Olympiastadion                 2
# Estadio Azteca                 2
# Estadio Monumental             1
# Maracanã Stadium               1
# Soccer City                    1
# International Stadium          1
# Stade de France                1
# Rose Bowl                      1
# Stadio Olimpico                1
# Santiago Bernabéu              1
# Estadio Centenario             1
# Stadio Nazionale PNF           1
# Wembley Stadium                1
# Estadio Nacional               1
# Råsunda Stadium                1
# Wankdorf Stadium               1
# [n 3]                          1
# Stade Olympique de Colombes    1
# Luzhniki Stadium               1
# Name: Venue, dtype: int64

# %%
df[df['Venue'].isin(['Estadio Azteca', 'Olympiastadion']) ].sort_values('Venue')
# Out:
#     Year       Winners                Score[2]    Runners-up           Venue  \
# 8   1970        Brazil                     4–1         Italy  Estadio Azteca
# 12  1986     Argentina                     3–2  West Germany  Estadio Azteca
# 9   1974  West Germany                     2–1   Netherlands  Olympiastadion
# 17  2006         Italy  1–1 (a.e.t.)(5–3 pen.)        France  Olympiastadion
#
#                 Location Attendance
# 8    Mexico City, Mexico     107412
# 12   Mexico City, Mexico     114600
# 9   Munich, West Germany      75200
# 17       Berlin, Germany      69000

# %%
df['Location'].value_counts()
# Out:
# Mexico City, Mexico           2
# Rome, Italy                   2
# Montevideo, Uruguay           1
# Madrid, Spain                 1
# Rio de Janeiro, Brazil        1
# Johannesburg, South Africa    1
# Berlin, Germany               1
# Yokohama, Japan               1
# Saint-Denis, France           1
# Pasadena, United States       1
# Munich, West Germany          1
# Buenos Aires, Argentina       1
# London, England               1
# Santiago, Chile               1
# Solna, Sweden                 1
# Bern, Switzerland             1
# [n 3]                         1
# Paris, France                 1
# Moscow, Russia                1
# Name: Location, dtype: int64

# %%
df = df.assign(country = (pd.Series([area.split(',')[-1]  for area in df['Location']])))

# %%
df['country'].value_counts()
# Out:
#  France           2
#  Mexico           2
#  Italy            2
#  Uruguay          1
#  Spain            1
#  Brazil           1
#  South Africa     1
#  Germany          1
#  Japan            1
#  United States    1
#  West Germany     1
#  Argentina        1
#  England          1
#  Chile            1
#  Sweden           1
#  Switzerland      1
# [n 3]             1
#  Russia           1
# Name: country, dtype: int64

# %%
np.round((len(df[df['Score[2]'].apply(lambda x: 'a.e.t' in x)])/len(df)*100),2)
# Out:
# 33.33

# %%
len(df[df['Score[2]'].apply(lambda x: 'pen' in x)]) /len(df[df['Score[2]'].apply(lambda x: 'a.e.t' in x)]) * 100
# Out:
# 28.57142857142857

# %%
df.drop(3)['Attendance'].astype(int).mean()
# Out:
# 76266.5

# %%
df['Runners-up'].value_counts()
# Out:
# Argentina         3
# West Germany      3
# Netherlands       3
# Czechoslovakia    2
# Hungary           2
# Brazil            2
# Italy             2
# Sweden            1
# Germany           1
# France            1
# Croatia           1
# Name: Runners-up, dtype: int64

# %%
df['Winners'].value_counts()
# Out:
# Brazil          5
# Italy           4
# West Germany    3
# Uruguay         2
# Argentina       2
# France          2
# England         1
# Spain           1
# Germany         1
# Name: Winners, dtype: int64
